# %%
import pandas as pd
from pathlib import Path
import numpy as np

# %%
def get_sig(df, gene):
    """Return significance value or None."""
    vals = df.loc[df["Gene(s)"] == gene, "Significance"]
    if len(vals) == 0:
        return None
    val = vals.iloc[0]
    return None if (isinstance(val, float) and np.isnan(val)) else val

severity_rank = {
    "Pathogenic": 6,
    "Likely pathogenic": 5,
    'Pathogenic/likely pathogenic/pathogenic, low penetrance': 4,
    "Risk factor": 4,
    "Association": 3,
    "Uncertain significance": 2,
    "Uncertain risk allele": 2,
    "Not provided": 1,
    None: 0,
}

def score_gene(info):
    return sum(severity_rank.get(v, 0) for v in info.values())


def build_overlap_info(gene_sets, snp_dfs, labels):
    overlap = set(gene_sets[0])
    for g in gene_sets[1:]:
        overlap &= set(g)

    overlap_info = {}

    for gene in overlap:
        entry = {}
        for label, df in zip(labels, snp_dfs):
            entry[label] = get_sig(df, gene)
        entry["score"] = score_gene(entry)
        overlap_info[gene] = entry

    return overlap_info

def rank_genes(overlap_info):
    return sorted(overlap_info.items(), key=lambda x: x[1]["score"], reverse=True)

# %%
son_snp_df = pd.read_csv(Path("data/hg002-son-snp.csv"), delimiter=",")
father_snp_df = pd.read_csv(Path("data/hg003-father-snp.csv"), delimiter=",")
mother_snp_df = pd.read_csv(Path("data/hg004-mother-snp.csv"), delimiter=",")

son_genes = list(son_snp_df["Gene(s)"])
father_genes = list(father_snp_df["Gene(s)"])
mother_genes = list(mother_snp_df["Gene(s)"])


overlap_3 = build_overlap_info(
    [son_genes, mother_genes, father_genes],
    [son_snp_df, mother_snp_df, father_snp_df],
    ["son", "mother", "father"]
)

overlap_mother_father = build_overlap_info(
    [mother_genes, father_genes],
    [mother_snp_df, father_snp_df],
    ["mother", "father"]
)

overlap_mother_son = build_overlap_info(
    [mother_genes, son_genes],
    [mother_snp_df, son_snp_df],
    ["mother", "son"]
)

overlap_father_son = build_overlap_info(
    [father_genes, son_genes],
    [father_snp_df, son_snp_df],
    ["father", "son"]
)


ranked_3 = rank_genes(overlap_3)
ranked_mother_father = rank_genes(overlap_mother_father)
ranked_mother_son = rank_genes(overlap_mother_son)
ranked_father_son = rank_genes(overlap_father_son)

print("\nTop overlapping genes (all members):")
for g, info in ranked_3:
    print(g, info)

print("\nTop overlapping genes (mother-father):")
for g, info in ranked_mother_father:
    print(g, info)

print("\nTop overlapping genes (mother-son):")
for g, info in ranked_mother_son:
    print(g, info)

print("\nTop overlapping genes (father-son):")
for g, info in ranked_father_son:
    print(g, info)
# Out:
# Top overlapping genes (all members):
# PERM1 {'son': 'Pathogenic', 'mother': 'Pathogenic', 'father': 'Pathogenic', 'score': 18}
# GBP1 {'son': 'Likely pathogenic', 'mother': 'Likely pathogenic', 'father': 'Likely pathogenic', 'score': 15}
# CHI3L1 {'son': 'Risk factor', 'mother': 'Risk factor', 'father': 'Risk factor', 'score': 12}
# FCGR2B {'son': 'Risk factor', 'mother': 'Risk factor', 'father': 'Risk factor', 'score': 12}
# ECE1 {'son': 'Risk factor', 'mother': 'Risk factor', 'father': 'Risk factor', 'score': 12}
# PADI2 {'son': 'Association', 'mother': 'Association', 'father': 'Association', 'score': 9}
# BGLAP, PAQR6 {'son': 'Association', 'mother': 'Association', 'father': 'Association', 'score': 9}
# CYP4Z1, CYP4A22-AS1 {'son': 'Association', 'mother': 'Association', 'father': 'Association', 'score': 9}
# MGST3 {'son': 'Association', 'mother': 'Association', 'father': 'Association', 'score': 9}
# TNFRSF1B {'son': 'Uncertain significance', 'mother': 'Uncertain significance', 'father': 'Uncertain significance', 'score': 6}
# FCGR3A {'son': 'Uncertain significance', 'mother': 'Uncertain significance', 'father': 'Uncertain significance', 'score': 6}
# ADAR {'son': 'Uncertain significance', 'mother': 'Uncertain significance', 'father': 'Uncertain significance', 'score': 6}
# NBPF1 {'son': 'Uncertain significance', 'mother': 'Uncertain significance', 'father': 'Uncertain significance', 'score': 6}
# CRP {'son': 'Uncertain significance', 'mother': 'Uncertain significance', 'father': 'Uncertain significance', 'score': 6}
# IL10, IL19 {'son': 'Uncertain risk allele', 'mother': 'Uncertain risk allele', 'father': 'Uncertain risk allele', 'score': 6}
# FCN3 {'son': 'Uncertain significance', 'mother': 'Uncertain significance', 'father': 'Uncertain significance', 'score': 6}
# PCSK9 {'son': None, 'mother': 'Uncertain significance', 'father': 'Uncertain significance', 'score': 4}
# APOA2 {'son': None, 'mother': 'Uncertain significance', 'father': 'Uncertain significance', 'score': 4}
# ABCA4 {'son': None, 'mother': None, 'father': 'Pathogenic/likely pathogenic/pathogenic, low penetrance', 'score': 4}
# SELENON {'son': None, 'mother': 'Uncertain significance', 'father': 'Uncertain significance', 'score': 4}
# RHCE {'son': 'Not provided', 'mother': 'Not provided', 'father': 'Not provided', 'score': 3}
# TNFRSF14 {'son': 'Not provided', 'mother': 'Not provided', 'father': 'Not provided', 'score': 3}
# TNFRSF14, TNFRSF14-AS1 {'son': 'Not provided', 'mother': 'Not provided', 'father': 'Not provided', 'score': 3}
# ZMPSTE24 {'son': 'Not provided', 'mother': 'Not provided', 'father': 'Not provided', 'score': 3}
# DISC1, TSNAX-DISC1 {'son': 'Not provided', 'mother': 'Not provided', 'father': 'Not provided', 'score': 3}
# CFH {'son': None, 'mother': None, 'father': None, 'score': 0}
# NDUFS2 {'son': None, 'mother': None, 'father': None, 'score': 0}
# FLVCR1 {'son': None, 'mother': None, 'father': None, 'score': 0}
# RYR2 {'son': None, 'mother': None, 'father': None, 'score': 0}
# ITPKB {'son': None, 'mother': None, 'father': None, 'score': 0}
# TOR1AIP1 {'son': None, 'mother': None, 'father': None, 'score': 0}
# SPTA1 {'son': None, 'mother': None, 'father': None, 'score': 0}
#
# Top overlapping genes (mother-father):
# PERM1 {'mother': 'Pathogenic', 'father': 'Pathogenic', 'score': 12}
# ITPKB, LOC129932672 {'mother': 'Likely pathogenic', 'father': 'Likely pathogenic', 'score': 10}
# GBP1 {'mother': 'Likely pathogenic', 'father': 'Likely pathogenic', 'score': 10}
# CHI3L1 {'mother': 'Risk factor', 'father': 'Risk factor', 'score': 8}
# FCGR2B {'mother': 'Risk factor', 'father': 'Risk factor', 'score': 8}
# ECE1 {'mother': 'Risk factor', 'father': 'Risk factor', 'score': 8}
# PADI2 {'mother': 'Association', 'father': 'Association', 'score': 6}
# BGLAP, PAQR6 {'mother': 'Association', 'father': 'Association', 'score': 6}
# CYP4Z1, CYP4A22-AS1 {'mother': 'Association', 'father': 'Association', 'score': 6}
# MGST3 {'mother': 'Association', 'father': 'Association', 'score': 6}
# APOA2 {'mother': 'Uncertain significance', 'father': 'Uncertain significance', 'score': 4}
# PCSK9 {'mother': 'Uncertain significance', 'father': 'Uncertain significance', 'score': 4}
# TNFRSF1B {'mother': 'Uncertain significance', 'father': 'Uncertain significance', 'score': 4}
# RD3 {'mother': 'Uncertain significance', 'father': 'Uncertain significance', 'score': 4}
# FCGR3A {'mother': 'Uncertain significance', 'father': 'Uncertain significance', 'score': 4}
# ABCA4 {'mother': None, 'father': 'Pathogenic/likely pathogenic/pathogenic, low penetrance', 'score': 4}
# ADAR {'mother': 'Uncertain significance', 'father': 'Uncertain significance', 'score': 4}
# FCN3 {'mother': 'Uncertain significance', 'father': 'Uncertain significance', 'score': 4}
# NBPF1 {'mother': 'Uncertain significance', 'father': 'Uncertain significance', 'score': 4}
# SELENON {'mother': 'Uncertain significance', 'father': 'Uncertain significance', 'score': 4}
# CRP {'mother': 'Uncertain significance', 'father': 'Uncertain significance', 'score': 4}
# SPTA1, OR10Z1 {'mother': 'Uncertain significance', 'father': 'Uncertain significance', 'score': 4}
# IL10, IL19 {'mother': 'Uncertain risk allele', 'father': 'Uncertain risk allele', 'score': 4}
# RHCE {'mother': 'Not provided', 'father': 'Not provided', 'score': 2}
# TNFRSF14 {'mother': 'Not provided', 'father': 'Not provided', 'score': 2}
# DPYD {'mother': 'Uncertain significance', 'father': 'Drug response', 'score': 2}
# TNFRSF14, TNFRSF14-AS1 {'mother': 'Not provided', 'father': 'Not provided', 'score': 2}
# ZMPSTE24 {'mother': 'Not provided', 'father': 'Not provided', 'score': 2}
# DISC1, TSNAX-DISC1 {'mother': 'Not provided', 'father': 'Not provided', 'score': 2}
# CFH {'mother': None, 'father': None, 'score': 0}
# TOR1AIP1 {'mother': None, 'father': None, 'score': 0}
# NDUFS2 {'mother': None, 'father': None, 'score': 0}
# TBX19 {'mother': None, 'father': None, 'score': 0}
# FLVCR1 {'mother': None, 'father': None, 'score': 0}
# RYR2 {'mother': None, 'father': None, 'score': 0}
# ITPKB {'mother': None, 'father': None, 'score': 0}
# MTR {'mother': None, 'father': None, 'score': 0}
# SPTA1 {'mother': None, 'father': None, 'score': 0}
#
# Top overlapping genes (mother-son):
# PERM1 {'mother': 'Pathogenic', 'son': 'Pathogenic', 'score': 12}
# GBP1 {'mother': 'Likely pathogenic', 'son': 'Likely pathogenic', 'score': 10}
# CHI3L1 {'mother': 'Risk factor', 'son': 'Risk factor', 'score': 8}
# CD244 {'mother': 'Risk factor', 'son': 'Risk factor', 'score': 8}
# FCGR2B {'mother': 'Risk factor', 'son': 'Risk factor', 'score': 8}
# USF1 {'mother': 'Risk factor', 'son': 'Risk factor', 'score': 8}
# ECE1 {'mother': 'Risk factor', 'son': 'Risk factor', 'score': 8}
# CYP4A22, CYP4A22-AS1 {'mother': 'Association', 'son': 'Association', 'score': 6}
# PADI2 {'mother': 'Association', 'son': 'Association', 'score': 6}
# BGLAP, PAQR6 {'mother': 'Association', 'son': 'Association', 'score': 6}
# SDC3 {'mother': 'Association', 'son': 'Association', 'score': 6}
# CYP4Z1, CYP4A22-AS1 {'mother': 'Association', 'son': 'Association', 'score': 6}
# PADI4 {'mother': 'Association', 'son': 'Association', 'score': 6}
# MGST3 {'mother': 'Association', 'son': 'Association', 'score': 6}
# FCER1A {'mother': 'Uncertain significance', 'son': 'Uncertain significance', 'score': 4}
# TNFRSF1B {'mother': 'Uncertain significance', 'son': 'Uncertain significance', 'score': 4}
# FCGR3A {'mother': 'Uncertain significance', 'son': 'Uncertain significance', 'score': 4}
# ADAR {'mother': 'Uncertain significance', 'son': 'Uncertain significance', 'score': 4}
# FCN3 {'mother': 'Uncertain significance', 'son': 'Uncertain significance', 'score': 4}
# NBPF1 {'mother': 'Uncertain significance', 'son': 'Uncertain significance', 'score': 4}
# CRP {'mother': 'Uncertain significance', 'son': 'Uncertain significance', 'score': 4}
# PINK1, PINK1-AS {'mother': 'Uncertain risk allele', 'son': 'Uncertain risk allele', 'score': 4}
# IL10, IL19 {'mother': 'Uncertain risk allele', 'son': 'Uncertain risk allele', 'score': 4}
# OBSCN {'mother': 'Uncertain significance', 'son': 'Uncertain significance', 'score': 4}
# RHCE {'mother': 'Not provided', 'son': 'Not provided', 'score': 2}
# TNFRSF14 {'mother': 'Not provided', 'son': 'Not provided', 'score': 2}
# APOA2 {'mother': 'Uncertain significance', 'son': None, 'score': 2}
# PCSK9 {'mother': 'Uncertain significance', 'son': None, 'score': 2}
# SELENON {'mother': 'Uncertain significance', 'son': None, 'score': 2}
# TNFRSF14, TNFRSF14-AS1 {'mother': 'Not provided', 'son': 'Not provided', 'score': 2}
# ZMPSTE24 {'mother': 'Not provided', 'son': 'Not provided', 'score': 2}
# DISC1, TSNAX-DISC1 {'mother': 'Not provided', 'son': 'Not provided', 'score': 2}
# DISC1, DISC2, TSNAX-DISC1 {'mother': 'Not provided', 'son': 'Not provided', 'score': 2}
# DBT {'mother': None, 'son': None, 'score': 0}
# CFH {'mother': None, 'son': None, 'score': 0}
# CCDST, FLG2 {'mother': None, 'son': None, 'score': 0}
# ABCA4 {'mother': None, 'son': None, 'score': 0}
# HSPG2 {'mother': None, 'son': None, 'score': 0}
# F5 {'mother': None, 'son': None, 'score': 0}
# NPHS2 {'mother': None, 'son': None, 'score': 0}
# NDUFS2 {'mother': None, 'son': None, 'score': 0}
# CLCNKB, LOC106501713 {'mother': None, 'son': None, 'score': 0}
# FLVCR1 {'mother': None, 'son': None, 'score': 0}
# FH {'mother': None, 'son': None, 'score': 0}
# RYR2 {'mother': None, 'son': None, 'score': 0}
# ITPKB {'mother': None, 'son': None, 'score': 0}
# TOR1AIP1 {'mother': None, 'son': None, 'score': 0}
# SPTA1 {'mother': None, 'son': None, 'score': 0}
#
# Top overlapping genes (father-son):
# PERM1 {'father': 'Pathogenic', 'son': 'Pathogenic', 'score': 12}
# GBP1 {'father': 'Likely pathogenic', 'son': 'Likely pathogenic', 'score': 10}
# CHI3L1 {'father': 'Risk factor', 'son': 'Risk factor', 'score': 8}
# FCGR2B {'father': 'Risk factor', 'son': 'Risk factor', 'score': 8}
# ECE1 {'father': 'Risk factor', 'son': 'Risk factor', 'score': 8}
# PADI2 {'father': 'Association', 'son': 'Association', 'score': 6}
# BGLAP, PAQR6 {'father': 'Association', 'son': 'Association', 'score': 6}
# CYP4Z1, CYP4A22-AS1 {'father': 'Association', 'son': 'Association', 'score': 6}
# MGST3 {'father': 'Association', 'son': 'Association', 'score': 6}
# MTARC2 {'father': 'Uncertain significance', 'son': 'Uncertain significance', 'score': 4}
# CR1 {'father': 'Uncertain significance', 'son': 'Uncertain significance', 'score': 4}
# TNFRSF1B {'father': 'Uncertain significance', 'son': 'Uncertain significance', 'score': 4}
# RGS2, LOC129932144 {'father': 'Uncertain significance', 'son': 'Uncertain significance', 'score': 4}
# PRAMEF17 {'father': 'Uncertain significance', 'son': 'Uncertain significance', 'score': 4}
# ABCA4 {'father': 'Pathogenic/likely pathogenic/pathogenic, low penetrance', 'son': None, 'score': 4}
# FCGR3A {'father': 'Uncertain significance', 'son': 'Uncertain significance', 'score': 4}
# ADAR {'father': 'Uncertain significance', 'son': 'Uncertain significance', 'score': 4}
# ARID1A {'father': 'Uncertain significance', 'son': 'Uncertain significance', 'score': 4}
# NBPF1 {'father': 'Uncertain significance', 'son': 'Uncertain significance', 'score': 4}
# CR2 {'father': 'Uncertain significance', 'son': 'Uncertain significance', 'score': 4}
# DYNLT4 {'father': 'Uncertain significance', 'son': 'Uncertain significance', 'score': 4}
# NPHP4 {'father': 'Uncertain significance', 'son': 'Uncertain significance', 'score': 4}
# CRP {'father': 'Uncertain significance', 'son': 'Uncertain significance', 'score': 4}
# MTARC1 {'father': 'Uncertain significance', 'son': 'Uncertain significance', 'score': 4}
# IL10, IL19 {'father': 'Uncertain risk allele', 'son': 'Uncertain risk allele', 'score': 4}
# FCN3 {'father': 'Uncertain significance', 'son': 'Uncertain significance', 'score': 4}
# RHCE {'father': 'Not provided', 'son': 'Not provided', 'score': 2}
# TNFRSF14 {'father': 'Not provided', 'son': 'Not provided', 'score': 2}
# APOA2 {'father': 'Uncertain significance', 'son': None, 'score': 2}
# PCSK9 {'father': 'Uncertain significance', 'son': None, 'score': 2}
# SELENON {'father': 'Uncertain significance', 'son': None, 'score': 2}
# TNFRSF14, TNFRSF14-AS1 {'father': 'Not provided', 'son': 'Not provided', 'score': 2}
# COQ8A {'father': 'Uncertain significance', 'son': None, 'score': 2}
# ZMPSTE24 {'father': 'Not provided', 'son': 'Not provided', 'score': 2}
# DISC1, TSNAX-DISC1 {'father': 'Not provided', 'son': 'Not provided', 'score': 2}
# SEMA4A {'father': None, 'son': None, 'score': 0}
# DIO1 {'father': 'Drug response', 'son': 'Drug response', 'score': 0}
# CFH {'father': None, 'son': None, 'score': 0}
# USH2A {'father': None, 'son': None, 'score': 0}
# NDUFS2 {'father': None, 'son': None, 'score': 0}
# MTHFR {'father': 'Drug response', 'son': 'Drug response', 'score': 0}
# FLVCR1 {'father': None, 'son': None, 'score': 0}
# RYR2 {'father': None, 'son': None, 'score': 0}
# CPT2 {'father': None, 'son': None, 'score': 0}
# CASQ2 {'father': None, 'son': None, 'score': 0}
# ITPKB {'father': None, 'son': None, 'score': 0}
# TOR1AIP1 {'father': None, 'son': None, 'score': 0}
# SPTA1 {'father': None, 'son': None, 'score': 0}
